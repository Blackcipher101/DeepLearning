# %% [markdown]
# <a href="https://colab.research.google.com/github/Blackcipher101/DeepLearning/blob/master/NLPcompare.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

import numpy as np

# %%
# Get the dataset.
# It has 70000 items, so might take a while to download
dataset, info = tfds.load('glue/sst2', with_info=True)
print(info.features)
print(info.features["label"].num_classes)
print(info.features["label"].names)
# Out:
# FeaturesDict({
#     'idx': tf.int32,
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
#     'sentence': Text(shape=(), dtype=tf.string),
# })
# 2
# ['negative', 'positive']

# %%
# Get the training and validation datasets
dataset_train, dataset_validation = dataset['train'], dataset['validation']
dataset_train
# Out:
# <PrefetchDataset shapes: {idx: (), label: (), sentence: ()}, types: {idx: tf.int32, label: tf.int64, sentence: tf.string}>

# %%
# Print some of the entries
for example in dataset_train.take(2):  
  review, label = example["sentence"], example["label"]
  print("Review:", review)
  print("Label: %d \n" % label.numpy())
# Out:
# Review: tf.Tensor(b'for the uninitiated plays better on video with the sound ', shape=(), dtype=string)
# Label: 0
#
# Review: tf.Tensor(b'like a giant commercial for universal studios , where much of the action takes place ', shape=(), dtype=string)
# Label: 0

# %%
# Get the sentences and the labels
# for both the training and the validation sets
training_reviews = []
training_labels = []
 
validation_reviews = []
validation_labels = []

# The dataset has 67,000 training entries, but that's a lot to process here!

# If you want to take the entire dataset: WARNING: takes longer!!
# for item in dataset_train.take(-1):

# Take 10,000 reviews
for item in dataset_train.take(10000):
  review, label = item["sentence"], item["label"]
  training_reviews.append(str(review.numpy()))
  training_labels.append(label.numpy())

print ("\nNumber of training reviews is: ", len(training_reviews))

# print some of the reviews and labels
for i in range(0, 2):
  print (training_reviews[i])
  print (training_labels[i])

# Get the validation data
# there's only about 800 items, so take them all
for item in dataset_validation.take(-1):  
  review, label = item["sentence"], item["label"]
  validation_reviews.append(str(review.numpy()))
  validation_labels.append(label.numpy())

print ("\nNumber of validation reviews is: ", len(validation_reviews))

# Print some of the validation reviews and labels
for i in range(0, 2):
  print (validation_reviews[i])
  print (validation_labels[i])
# Out:
# Number of training reviews is:  10000
# b'for the uninitiated plays better on video with the sound '
# 0
# b'like a giant commercial for universal studios , where much of the action takes place '
# 0
#
# Number of validation reviews is:  872
# b'a valueless kiddie paean to pro basketball underwritten by the nba . '
# 0
# b"featuring a dangerously seductive performance from the great daniel auteuil , `` sade '' covers the same period as kaufmann 's `` quills '' with more unsettlingly realistic results . "
# 1

# %%
# There's a total of 21224 words in the reviews
# but many of them are irrelevant like with, it, of, on.
# If we take a subset of the training data, then the vocab
# will be smaller.

# A reasonable review might have about 50 words or so,
# so we can set max_length to 50 (but feel free to change it as you like)

vocab_size = 4000
embedding_dim = 16
max_length = 50
trunc_type='post'
pad_type='post'
oov_tok = "<OOV>"

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_reviews)
word_index = tokenizer.word_index

# %%
# Pad the sequences so that they are all the same length
training_sequences = tokenizer.texts_to_sequences(training_reviews)
training_padded = pad_sequences(training_sequences,maxlen=max_length, 
                                truncating=trunc_type, padding=pad_type)

validation_sequences = tokenizer.texts_to_sequences(validation_reviews)
validation_padded = pad_sequences(validation_sequences,maxlen=max_length)

training_labels_final = np.array(training_labels)
validation_labels_final = np.array(validation_labels)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),  
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 16)            64000
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 17
# =================================================================
# Total params: 64,017
# Trainable params: 64,017
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 20
history = model.fit(training_padded, training_labels_final, epochs=num_epochs, 
                    validation_data=(validation_padded, validation_labels_final))
# Out:
# Epoch 1/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6841 - accuracy: 0.5565 - val_loss: 0.6916 - val_accuracy: 0.5126
# Epoch 2/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6748 - accuracy: 0.5669 - val_loss: 0.6769 - val_accuracy: 0.5642
# Epoch 3/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6567 - accuracy: 0.6077 - val_loss: 0.6520 - val_accuracy: 0.6502
# Epoch 4/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6291 - accuracy: 0.6622 - val_loss: 0.6227 - val_accuracy: 0.6961
# Epoch 5/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5967 - accuracy: 0.7033 - val_loss: 0.5893 - val_accuracy: 0.7144
# Epoch 6/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5628 - accuracy: 0.7340 - val_loss: 0.5614 - val_accuracy: 0.7362
# Epoch 7/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5309 - accuracy: 0.7627 - val_loss: 0.5371 - val_accuracy: 0.7466
# Epoch 8/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5011 - accuracy: 0.7866 - val_loss: 0.5190 - val_accuracy: 0.7546
# Epoch 9/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4749 - accuracy: 0.8022 - val_loss: 0.5056 - val_accuracy: 0.7592
# Epoch 10/20
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4508 - accuracy: 0.8146 - val_loss: 0.4968 - val_accuracy: 0.7557
# Epoch 11/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4295 - accuracy: 0.8249 - val_loss: 0.4916 - val_accuracy: 0.7580
# Epoch 12/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4109 - accuracy: 0.8326 - val_loss: 0.4858 - val_accuracy: 0.7603
# Epoch 13/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3934 - accuracy: 0.8410 - val_loss: 0.4849 - val_accuracy: 0.7718
# Epoch 14/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3788 - accuracy: 0.8463 - val_loss: 0.4884 - val_accuracy: 0.7592
# Epoch 15/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3640 - accuracy: 0.8527 - val_loss: 0.4869 - val_accuracy: 0.7718
# Epoch 16/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3517 - accuracy: 0.8551 - val_loss: 0.4918 - val_accuracy: 0.7649
# Epoch 17/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3401 - accuracy: 0.8573 - val_loss: 0.4949 - val_accuracy: 0.7775
# Epoch 18/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3293 - accuracy: 0.8630 - val_loss: 0.5030 - val_accuracy: 0.7741
# Epoch 19/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3195 - accuracy: 0.8652 - val_loss: 0.5099 - val_accuracy: 0.7695
# Epoch 20/20
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3103 - accuracy: 0.8707 - val_loss: 0.5167 - val_accuracy: 0.7775

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()
  
plot_graphs(history, "accuracy")
plot_graphs(history, "loss")

# %%
# Write some new reviews 

review1 = """I loved this movie"""

review2 = """that was the worst movie I've ever seen"""

review3 = """too much violence even for a Bond film"""

review4 = """a captivating recounting of a cherished myth"""

new_reviews = [review1, review2, review3, review4]

# %%
# Define a function to prepare the new reviews for use with a model
# and then use the model to predict the sentiment of the new reviews           

def predict_review(model, reviews):
  # Create the sequences
  padding_type='post'
  sample_sequences = tokenizer.texts_to_sequences(reviews)
  reviews_padded = pad_sequences(sample_sequences, padding=padding_type, 
                                 maxlen=max_length) 
  classes = model.predict(reviews_padded)
  for x in range(len(reviews_padded)):
    print(reviews[x])
    print(classes[x])
    print('\n')

predict_review(model, new_reviews)
# Out:
# I loved this movie
# [0.35436213]
#
#
# that was the worst movie I've ever seen
# [0.106071]
#
#
# too much violence even for a Bond film
# [0.02794168]
#
#
# a captivating recounting of a cherished myth
# [0.57860714]

# %%
def fit_model_and_show_results (model, reviews):
  model.summary()
  history = model.fit(training_padded, training_labels_final, epochs=num_epochs, 
                      validation_data=(validation_padded, validation_labels_final))
  plot_graphs(history, "accuracy")
  plot_graphs(history, "loss")
  predict_review(model, reviews)

# %%
num_epochs = 30

model_cnn = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(16, 5, activation='relu'),
    tf.keras.layers.GlobalMaxPooling1D(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Default learning rate for the Adam optimizer is 0.001
# Let's slow down the learning rate by 10.
learning_rate = 0.0001
model_cnn.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate), 
                  metrics=['accuracy'])

fit_model_and_show_results(model_cnn, new_reviews)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 16)            64000
# _________________________________________________________________
# conv1d (Conv1D)              (None, 46, 16)            1296
# _________________________________________________________________
# global_max_pooling1d (Global (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 65,313
# Trainable params: 65,313
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6902 - accuracy: 0.5358 - val_loss: 0.6922 - val_accuracy: 0.5149
# Epoch 2/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6822 - accuracy: 0.5598 - val_loss: 0.6910 - val_accuracy: 0.5103
# Epoch 3/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6771 - accuracy: 0.5603 - val_loss: 0.6884 - val_accuracy: 0.5138
# Epoch 4/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6707 - accuracy: 0.5726 - val_loss: 0.6837 - val_accuracy: 0.5573
# Epoch 5/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6616 - accuracy: 0.6101 - val_loss: 0.6762 - val_accuracy: 0.6468
# Epoch 6/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6484 - accuracy: 0.6578 - val_loss: 0.6658 - val_accuracy: 0.6858
# Epoch 7/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6303 - accuracy: 0.7030 - val_loss: 0.6531 - val_accuracy: 0.7064
# Epoch 8/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.6078 - accuracy: 0.7251 - val_loss: 0.6404 - val_accuracy: 0.6972
# Epoch 9/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5819 - accuracy: 0.7533 - val_loss: 0.6280 - val_accuracy: 0.6995
# Epoch 10/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5542 - accuracy: 0.7723 - val_loss: 0.6146 - val_accuracy: 0.7144
# Epoch 11/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.5257 - accuracy: 0.7894 - val_loss: 0.6024 - val_accuracy: 0.7213
# Epoch 12/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4975 - accuracy: 0.8050 - val_loss: 0.5899 - val_accuracy: 0.7259
# Epoch 13/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4707 - accuracy: 0.8147 - val_loss: 0.5819 - val_accuracy: 0.7305
# Epoch 14/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4454 - accuracy: 0.8248 - val_loss: 0.5730 - val_accuracy: 0.7328
# Epoch 15/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4222 - accuracy: 0.8318 - val_loss: 0.5580 - val_accuracy: 0.7477
# Epoch 16/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.4010 - accuracy: 0.8399 - val_loss: 0.5482 - val_accuracy: 0.7489
# Epoch 17/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3816 - accuracy: 0.8465 - val_loss: 0.5413 - val_accuracy: 0.7466
# Epoch 18/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3641 - accuracy: 0.8525 - val_loss: 0.5368 - val_accuracy: 0.7477
# Epoch 19/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3479 - accuracy: 0.8610 - val_loss: 0.5297 - val_accuracy: 0.7454
# Epoch 20/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3332 - accuracy: 0.8647 - val_loss: 0.5238 - val_accuracy: 0.7466
# Epoch 21/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3196 - accuracy: 0.8689 - val_loss: 0.5218 - val_accuracy: 0.7443
# Epoch 22/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3073 - accuracy: 0.8764 - val_loss: 0.5157 - val_accuracy: 0.7546
# Epoch 23/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2957 - accuracy: 0.8810 - val_loss: 0.5156 - val_accuracy: 0.7523
# Epoch 24/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2852 - accuracy: 0.8848 - val_loss: 0.5187 - val_accuracy: 0.7557
# Epoch 25/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2753 - accuracy: 0.8868 - val_loss: 0.5199 - val_accuracy: 0.7557
# Epoch 26/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2661 - accuracy: 0.8904 - val_loss: 0.5213 - val_accuracy: 0.7592
# Epoch 27/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2578 - accuracy: 0.8912 - val_loss: 0.5237 - val_accuracy: 0.7592
# Epoch 28/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2498 - accuracy: 0.8944 - val_loss: 0.5289 - val_accuracy: 0.7615
# Epoch 29/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2422 - accuracy: 0.8981 - val_loss: 0.5345 - val_accuracy: 0.7569
# Epoch 30/30
# 313/313 [==============================] - 1s 4ms/step - loss: 0.2352 - accuracy: 0.9009 - val_loss: 0.5420 - val_accuracy: 0.7534
# I loved this movie
# [0.9331934]
#
#
# that was the worst movie I've ever seen
# [0.07145087]
#
#
# too much violence even for a Bond film
# [0.00848554]
#
#
# a captivating recounting of a cherished myth
# [0.7856515]

# %%
num_epochs = 30

model_gru = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003 # slower than the default learning rate
model_gru.compile(loss='binary_crossentropy',
                  optimizer=tf.keras.optimizers.Adam(learning_rate),
                  metrics=['accuracy'])

fit_model_and_show_results(model_gru, new_reviews)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, 50, 16)            64000
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                9600
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 73,665
# Trainable params: 73,665
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6905 - accuracy: 0.5582 - val_loss: 0.6931 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6872 - accuracy: 0.5590 - val_loss: 0.6939 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6854 - accuracy: 0.5590 - val_loss: 0.6949 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6843 - accuracy: 0.5590 - val_loss: 0.6957 - val_accuracy: 0.5092
# Epoch 5/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6830 - accuracy: 0.5590 - val_loss: 0.6966 - val_accuracy: 0.5092
# Epoch 6/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6812 - accuracy: 0.5590 - val_loss: 0.6976 - val_accuracy: 0.5092
# Epoch 7/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6783 - accuracy: 0.5590 - val_loss: 0.6993 - val_accuracy: 0.5092
# Epoch 8/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6737 - accuracy: 0.5590 - val_loss: 0.7029 - val_accuracy: 0.5092
# Epoch 9/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6659 - accuracy: 0.5643 - val_loss: 0.7109 - val_accuracy: 0.5092
# Epoch 10/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6528 - accuracy: 0.5927 - val_loss: 0.7188 - val_accuracy: 0.5092
# Epoch 11/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6324 - accuracy: 0.6426 - val_loss: 0.7147 - val_accuracy: 0.5092
# Epoch 12/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6018 - accuracy: 0.6716 - val_loss: 0.6604 - val_accuracy: 0.5103
# Epoch 13/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5702 - accuracy: 0.7034 - val_loss: 0.6267 - val_accuracy: 0.5367
# Epoch 14/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5478 - accuracy: 0.7250 - val_loss: 0.6363 - val_accuracy: 0.5573
# Epoch 15/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5297 - accuracy: 0.7384 - val_loss: 0.6335 - val_accuracy: 0.6032
# Epoch 16/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5125 - accuracy: 0.7533 - val_loss: 0.6217 - val_accuracy: 0.6514
# Epoch 17/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4955 - accuracy: 0.7639 - val_loss: 0.6121 - val_accuracy: 0.7248
# Epoch 18/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4788 - accuracy: 0.7760 - val_loss: 0.6208 - val_accuracy: 0.7156
# Epoch 19/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4648 - accuracy: 0.7868 - val_loss: 0.6002 - val_accuracy: 0.7477
# Epoch 20/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4510 - accuracy: 0.7951 - val_loss: 0.5870 - val_accuracy: 0.7339
# Epoch 21/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4403 - accuracy: 0.8025 - val_loss: 0.5909 - val_accuracy: 0.7580
# Epoch 22/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4263 - accuracy: 0.8106 - val_loss: 0.5823 - val_accuracy: 0.7592
# Epoch 23/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4185 - accuracy: 0.8163 - val_loss: 0.5918 - val_accuracy: 0.7661
# Epoch 24/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4084 - accuracy: 0.8221 - val_loss: 0.5868 - val_accuracy: 0.7661
# Epoch 25/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3993 - accuracy: 0.8271 - val_loss: 0.5973 - val_accuracy: 0.7615
# Epoch 26/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3916 - accuracy: 0.8310 - val_loss: 0.5917 - val_accuracy: 0.7592
# Epoch 27/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3849 - accuracy: 0.8358 - val_loss: 0.6126 - val_accuracy: 0.7569
# Epoch 28/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3774 - accuracy: 0.8386 - val_loss: 0.6266 - val_accuracy: 0.7546
# Epoch 29/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3709 - accuracy: 0.8425 - val_loss: 0.5987 - val_accuracy: 0.7534
# Epoch 30/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.3645 - accuracy: 0.8447 - val_loss: 0.6322 - val_accuracy: 0.7638
# I loved this movie
# [0.43856388]
#
#
# that was the worst movie I've ever seen
# [0.1640286]
#
#
# too much violence even for a Bond film
# [0.11348309]
#
#
# a captivating recounting of a cherished myth
# [0.5312245]

# %%
num_epochs = 30

model_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)), 
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.00003
model_bidi_lstm.compile(loss='binary_crossentropy',
                        optimizer=tf.keras.optimizers.Adam(learning_rate),
                        metrics=['accuracy'])
fit_model_and_show_results(model_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 50, 16)            64000
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 32)                4224
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 68,257
# Trainable params: 68,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 3s 11ms/step - loss: 0.6910 - accuracy: 0.5551 - val_loss: 0.6932 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6875 - accuracy: 0.5590 - val_loss: 0.6944 - val_accuracy: 0.5092
# Epoch 3/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6851 - accuracy: 0.5590 - val_loss: 0.6963 - val_accuracy: 0.5092
# Epoch 4/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6836 - accuracy: 0.5590 - val_loss: 0.6985 - val_accuracy: 0.5092
# Epoch 5/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6824 - accuracy: 0.5590 - val_loss: 0.7004 - val_accuracy: 0.5092
# Epoch 6/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6810 - accuracy: 0.5590 - val_loss: 0.7026 - val_accuracy: 0.5092
# Epoch 7/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6793 - accuracy: 0.5590 - val_loss: 0.7046 - val_accuracy: 0.5092
# Epoch 8/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6773 - accuracy: 0.5590 - val_loss: 0.7082 - val_accuracy: 0.5092
# Epoch 9/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6749 - accuracy: 0.5590 - val_loss: 0.7111 - val_accuracy: 0.5092
# Epoch 10/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6721 - accuracy: 0.5603 - val_loss: 0.7142 - val_accuracy: 0.5092
# Epoch 11/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6688 - accuracy: 0.5672 - val_loss: 0.7176 - val_accuracy: 0.5092
# Epoch 12/30
# 313/313 [==============================] - 3s 10ms/step - loss: 0.6651 - accuracy: 0.5829 - val_loss: 0.7229 - val_accuracy: 0.5092
# Epoch 13/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6609 - accuracy: 0.5985 - val_loss: 0.7258 - val_accuracy: 0.5092
# Epoch 14/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6561 - accuracy: 0.6123 - val_loss: 0.7261 - val_accuracy: 0.5092
# Epoch 15/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6505 - accuracy: 0.6263 - val_loss: 0.7300 - val_accuracy: 0.5092
# Epoch 16/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6440 - accuracy: 0.6368 - val_loss: 0.7304 - val_accuracy: 0.5092
# Epoch 17/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6361 - accuracy: 0.6470 - val_loss: 0.7261 - val_accuracy: 0.5092
# Epoch 18/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6268 - accuracy: 0.6594 - val_loss: 0.7317 - val_accuracy: 0.5092
# Epoch 19/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6154 - accuracy: 0.6673 - val_loss: 0.7191 - val_accuracy: 0.5092
# Epoch 20/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.6018 - accuracy: 0.6800 - val_loss: 0.7059 - val_accuracy: 0.5092
# Epoch 21/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5856 - accuracy: 0.6946 - val_loss: 0.6835 - val_accuracy: 0.5103
# Epoch 22/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5682 - accuracy: 0.7147 - val_loss: 0.6543 - val_accuracy: 0.5115
# Epoch 23/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5498 - accuracy: 0.7332 - val_loss: 0.6231 - val_accuracy: 0.5206
# Epoch 24/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5336 - accuracy: 0.7540 - val_loss: 0.5990 - val_accuracy: 0.5826
# Epoch 25/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5197 - accuracy: 0.7671 - val_loss: 0.5758 - val_accuracy: 0.7053
# Epoch 26/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.5082 - accuracy: 0.7762 - val_loss: 0.5632 - val_accuracy: 0.7236
# Epoch 27/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4975 - accuracy: 0.7865 - val_loss: 0.5528 - val_accuracy: 0.7420
# Epoch 28/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4877 - accuracy: 0.7894 - val_loss: 0.5483 - val_accuracy: 0.7408
# Epoch 29/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4788 - accuracy: 0.7982 - val_loss: 0.5383 - val_accuracy: 0.7546
# Epoch 30/30
# 313/313 [==============================] - 3s 9ms/step - loss: 0.4697 - accuracy: 0.8028 - val_loss: 0.5363 - val_accuracy: 0.7546
# I loved this movie
# [0.48904595]
#
#
# that was the worst movie I've ever seen
# [0.33400574]
#
#
# too much violence even for a Bond film
# [0.41879234]
#
#
# a captivating recounting of a cherished myth
# [0.56391704]

# %%
num_epochs = 30

model_multiple_bidi_lstm = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim, 
                                                       return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(embedding_dim)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

learning_rate = 0.0003
model_multiple_bidi_lstm.compile(loss='binary_crossentropy',
                                 optimizer=tf.keras.optimizers.Adam(learning_rate),
                                 metrics=['accuracy'])
fit_model_and_show_results(model_multiple_bidi_lstm, new_reviews)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, 50, 16)            64000
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 50, 32)            4224
# _________________________________________________________________
# bidirectional_3 (Bidirection (None, 32)                6272
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 74,529
# Trainable params: 74,529
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 313/313 [==============================] - 6s 19ms/step - loss: 0.6814 - accuracy: 0.5650 - val_loss: 0.7268 - val_accuracy: 0.5092
# Epoch 2/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.4984 - accuracy: 0.7555 - val_loss: 0.6801 - val_accuracy: 0.5585
# Epoch 3/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3583 - accuracy: 0.8393 - val_loss: 0.6470 - val_accuracy: 0.6296
# Epoch 4/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.3020 - accuracy: 0.8633 - val_loss: 0.6784 - val_accuracy: 0.5493
# Epoch 5/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2692 - accuracy: 0.8778 - val_loss: 0.6823 - val_accuracy: 0.5287
# Epoch 6/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2491 - accuracy: 0.8877 - val_loss: 0.6756 - val_accuracy: 0.5505
# Epoch 7/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2322 - accuracy: 0.8946 - val_loss: 0.6734 - val_accuracy: 0.5482
# Epoch 8/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2233 - accuracy: 0.8983 - val_loss: 0.6866 - val_accuracy: 0.5195
# Epoch 9/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2103 - accuracy: 0.9004 - val_loss: 0.7323 - val_accuracy: 0.5206
# Epoch 10/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.2033 - accuracy: 0.9041 - val_loss: 0.7032 - val_accuracy: 0.4908
# Epoch 11/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1951 - accuracy: 0.9109 - val_loss: 0.7047 - val_accuracy: 0.4759
# Epoch 12/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1915 - accuracy: 0.9087 - val_loss: 0.7407 - val_accuracy: 0.4106
# Epoch 13/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1842 - accuracy: 0.9112 - val_loss: 0.7265 - val_accuracy: 0.4472
# Epoch 14/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1800 - accuracy: 0.9156 - val_loss: 0.8961 - val_accuracy: 0.5023
# Epoch 15/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1772 - accuracy: 0.9160 - val_loss: 0.8589 - val_accuracy: 0.4954
# Epoch 16/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1711 - accuracy: 0.9193 - val_loss: 0.7863 - val_accuracy: 0.3979
# Epoch 17/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1657 - accuracy: 0.9207 - val_loss: 0.8725 - val_accuracy: 0.3991
# Epoch 18/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1665 - accuracy: 0.9203 - val_loss: 0.8934 - val_accuracy: 0.4197
# Epoch 19/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1645 - accuracy: 0.9210 - val_loss: 0.9289 - val_accuracy: 0.4220
# Epoch 20/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1607 - accuracy: 0.9232 - val_loss: 1.0122 - val_accuracy: 0.4048
# Epoch 21/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1584 - accuracy: 0.9218 - val_loss: 0.8643 - val_accuracy: 0.4071
# Epoch 22/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1567 - accuracy: 0.9209 - val_loss: 0.9125 - val_accuracy: 0.4289
# Epoch 23/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1552 - accuracy: 0.9244 - val_loss: 0.9911 - val_accuracy: 0.3452
# Epoch 24/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1541 - accuracy: 0.9249 - val_loss: 1.1242 - val_accuracy: 0.4094
# Epoch 25/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1511 - accuracy: 0.9245 - val_loss: 1.0004 - val_accuracy: 0.4587
# Epoch 26/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1493 - accuracy: 0.9256 - val_loss: 0.9320 - val_accuracy: 0.3727
# Epoch 27/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1491 - accuracy: 0.9244 - val_loss: 0.8743 - val_accuracy: 0.4862
# Epoch 28/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1480 - accuracy: 0.9280 - val_loss: 1.1298 - val_accuracy: 0.5011
# Epoch 29/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1442 - accuracy: 0.9266 - val_loss: 1.1898 - val_accuracy: 0.4484
# Epoch 30/30
# 313/313 [==============================] - 5s 15ms/step - loss: 0.1455 - accuracy: 0.9276 - val_loss: 1.1085 - val_accuracy: 0.4002
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7faccc590e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7faccc590e18> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# I loved this movie
# [0.3779872]
#
#
# that was the worst movie I've ever seen
# [0.5939387]
#
#
# too much violence even for a Bond film
# [0.01166103]
#
#
# a captivating recounting of a cherished myth
# [0.99556005]
